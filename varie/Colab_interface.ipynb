# %% [markdown]
# <a href="https://colab.research.google.com/github/Dario-Maglio/Numerical_Methods/blob/main/varie/Colab_interface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Colab interface for the "Metodi numerici" course
#
#
#
# 1.   Monte Carlo simulation -> Prof. D'Elia
# 2.   Quantum Ising 1D -> Prof. Rossini
# 3.   Path integral simulation -> Prof. D'Elia

# %% [markdown]
# #Get started

# %% [markdown]
# Taking attention to the path of the folder we are working in

# %%
# !pwd                     # show current path

# %% [markdown]
# Download useful packages and import python modules

# %%
# !apt-get install git
# !pip install numpy matplotlib

# %%
import os

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Clone the repository and change the current directory

# %%
# !git clone https://github.com/Dario-Maglio/Numerical_methods.git
# %cd Numerical_methods/
# Out:
# Cloning into 'Numerical_methods'...
# remote: Enumerating objects: 1255, done.
# remote: Total 1255 (delta 0), reused 0 (delta 0), pack-reused 1255
# Receiving objects: 100% (1255/1255), 204.00 MiB | 20.40 MiB/s, done.
# Resolving deltas: 100% (254/254), done.
# Checking out files: 100% (486/486), done.
# /content/Numerical_methods

# %% [markdown]
# #Module 1
#
# Monte Carlo simulation

# %%
# %cd Application_projects/Ising_model_2D/
# Out:
# /content/Numerical_methods/Application_projects/Ising_model_2D

# %%
# !touch  anna_metropolis.cpp

# %%
# !rm  anna_file_prova.cpp

# %% [markdown]
# Execute programs

# %%
# With bash commands
# !g++ data_analysis.cpp -o data.out
# !./data.out

# With python commands
#os.system('gfortran ising.f -o run_ising')
#os.system('!./run_ising')
# Out:
# Output streaming troncato alle ultime 5000 righe.
# 30 0.45 ---energy error:
# logging: k steps 1 -> -1.508 ± 0.000838778
# logging: k steps 2 -> -1.508 ± 0.00106767
# logging: k steps 3 -> -1.508 ± 0.00135832
# logging: k steps 4 -> -1.508 ± 0.00171446
# logging: k steps 5 -> -1.508 ± 0.00211354
# 30 0.45 ---magnetization error:
# logging: k steps 1 -> 0.739371 ± 0.00138345
# logging: k steps 2 -> 0.739371 ± 0.00191616
# logging: k steps 3 -> 0.739371 ± 0.00262969
# logging: k steps 4 -> 0.739371 ± 0.003536
# logging: k steps 5 -> 0.739371 ± 0.00461808
# 30 0.45 --- C error:
# logging: correl lenght 8 -> 4.41605e-07 ± 7.60036e-09
# logging: correl lenght 16 -> 4.40323e-07 ± 9.6427e-09
# logging: correl lenght 32 -> 4.41577e-07 ± 1.08456e-08
# logging: correl lenght 64 -> 4.39942e-07 ± 1.12404e-08
# logging: correl lenght 128 -> 4.43909e-07 ± 1.43731e-08
# 30 0.45 --- Ki error:
# logging: correl lenght 8 -> 9.90967e-07 ± 5.26652e-08
# logging: correl lenght 16 -> 9.92655e-07 ± 6.36291e-08
# logging: correl lenght 32 -> 9.97983e-07 ± 8.88819e-08
# logging: correl lenght 64 -> 1.00468e-06 ± 1.1062e-07
# logging: correl lenght 128 -> 9.95238e-07 ± 1.10377e-07
# 30 0.4525 ---energy error:
# logging: k steps 1 -> -1.53035 ± 0.000803685
# logging: k steps 2 -> -1.53035 ± 0.00101526
# logging: k steps 3 -> -1.53035 ± 0.00127679
# logging: k steps 4 -> -1.53035 ± 0.00155906
# logging: k steps 5 -> -1.53035 ± 0.00186568
# 30 0.4525 ---magnetization error:
# logging: k steps 1 -> 0.769297 ± 0.00111805
# logging: k steps 2 -> 0.769297 ± 0.00153584
# logging: k steps 3 -> 0.769297 ± 0.00208589
# logging: k steps 4 -> 0.769297 ± 0.0027616
# logging: k steps 5 -> 0.769297 ± 0.00354143
# 30 0.4525 --- C error:
# logging: correl lenght 8 -> 4.14371e-07 ± 6.85052e-09
# logging: correl lenght 16 -> 4.12788e-07 ± 9.12181e-09
# logging: correl lenght 32 -> 4.13864e-07 ± 1.08178e-08
# logging: correl lenght 64 -> 4.13103e-07 ± 1.20939e-08
# logging: correl lenght 128 -> 4.13112e-07 ± 1.39657e-08
# 30 0.4525 --- Ki error:
# logging: correl lenght 8 -> 6.57614e-07 ± 3.89518e-08
# logging: correl lenght 16 -> 6.66477e-07 ± 5.42463e-08
# logging: correl lenght 32 -> 6.69208e-07 ± 7.12169e-08
# logging: correl lenght 64 -> 6.67152e-07 ± 9.50522e-08
# logging: correl lenght 128 -> 6.56963e-07 ± 1.06878e-07
# 30 0.455 ---energy error:
# logging: k steps 1 -> -1.54897 ± 0.000740116
# logging: k steps 2 -> -1.54897 ± 0.000911476
# logging: k steps 3 -> -1.54897 ± 0.00111086
# logging: k steps 4 -> -1.54897 ± 0.00131586
# logging: k steps 5 -> -1.54897 ± 0.0015379
# 30 0.455 ---magnetization error:
# logging: k steps 1 -> 0.788656 ± 0.000862403
# logging: k steps 2 -> 0.788656 ± 0.00116451
# logging: k steps 3 -> 0.788656 ± 0.00154289
# logging: k steps 4 -> 0.788656 ± 0.00196302
# logging: k steps 5 -> 0.788656 ± 0.00239794
# 30 0.455 --- C error:
# logging: correl lenght 8 -> 3.62519e-07 ± 6.00598e-09
# logging: correl lenght 16 -> 3.633e-07 ± 6.08724e-09
# logging: correl lenght 32 -> 3.62549e-07 ± 7.35222e-09
# logging: correl lenght 64 -> 3.62195e-07 ± 9.63491e-09
# logging: correl lenght 128 -> 3.6272e-07 ± 9.46096e-09
# 30 0.455 --- Ki error:
# logging: correl lenght 8 -> 4.02687e-07 ± 1.70302e-08
# logging: correl lenght 16 -> 4.02163e-07 ± 2.27532e-08
# logging: correl lenght 32 -> 4.0426e-07 ± 2.53319e-08
# logging: correl lenght 64 -> 3.98479e-07 ± 2.52871e-08
# logging: correl lenght 128 -> 4.06269e-07 ± 3.31427e-08
# 30 0.4575 ---energy error:
# logging: k steps 1 -> -1.56417 ± 0.000699964
# logging: k steps 2 -> -1.56417 ± 0.00085392
# logging: k steps 3 -> -1.56417 ± 0.00102487
# logging: k steps 4 -> -1.56417 ± 0.0011907
# logging: k steps 5 -> -1.56417 ± 0.00138168
# 30 0.4575 ---magnetization error:
# logging: k steps 1 -> 0.802663 ± 0.000811275
# logging: k steps 2 -> 0.802663 ± 0.00109655
# logging: k steps 3 -> 0.802663 ± 0.0014524
# logging: k steps 4 -> 0.802663 ± 0.00187389
# logging: k steps 5 -> 0.802663 ± 0.00232732
# 30 0.4575 --- C error:
# logging: correl lenght 8 -> 3.32657e-07 ± 5.67201e-09
# logging: correl lenght 16 -> 3.33135e-07 ± 7.15129e-09
# logging: correl lenght 32 -> 3.31829e-07 ± 8.02524e-09
# logging: correl lenght 64 -> 3.31275e-07 ± 9.6323e-09
# logging: correl lenght 128 -> 3.32725e-07 ± 8.42668e-09
# 30 0.4575 --- Ki error:
# logging: correl lenght 8 -> 3.55451e-07 ± 3.29486e-08
# logging: correl lenght 16 -> 3.60308e-07 ± 4.09895e-08
# logging: correl lenght 32 -> 3.57603e-07 ± 6.10008e-08
# logging: correl lenght 64 -> 3.62895e-07 ± 6.52584e-08
# logging: correl lenght 128 -> 3.54318e-07 ± 7.73832e-08
# 30 0.46 ---energy error:
# logging: k steps 1 -> -1.58102 ± 0.000697581
# logging: k steps 2 -> -1.58102 ± 0.000852854
# logging: k steps 3 -> -1.58102 ± 0.00103328
# logging: k steps 4 -> -1.58102 ± 0.00121269
# logging: k steps 5 -> -1.58102 ± 0.00137164
# 30 0.46 ---magnetization error:
# logging: k steps 1 -> 0.814039 ± 0.000782726
# logging: k steps 2 -> 0.814039 ± 0.00105451
# logging: k steps 3 -> 0.814039 ± 0.00139895
# logging: k steps 4 -> 0.814039 ± 0.00180442
# logging: k steps 5 -> 0.814039 ± 0.00222754
# 30 0.46 --- C error:
# logging: correl lenght 8 -> 3.30212e-07 ± 5.10355e-09
# logging: correl lenght 16 -> 3.29668e-07 ± 5.5127e-09
# logging: correl lenght 32 -> 3.30341e-07 ± 7.18638e-09
# logging: correl lenght 64 -> 3.29728e-07 ± 8.78425e-09
# logging: correl lenght 128 -> 3.28374e-07 ± 9.23347e-09
# 30 0.46 --- Ki error:
# logging: correl lenght 8 -> 3.30261e-07 ± 2.4293e-08
# logging: correl lenght 16 -> 3.33373e-07 ± 4.07143e-08
# logging: correl lenght 32 -> 3.27676e-07 ± 4.60234e-08
# logging: correl lenght 64 -> 3.30426e-07 ± 5.19756e-08
# logging: correl lenght 128 -> 3.25537e-07 ± 7.08612e-08
# 30 0.4625 ---energy error:
# logging: k steps 1 -> -1.5955 ± 0.000674721
# logging: k steps 2 -> -1.5955 ± 0.000813712
# logging: k steps 3 -> -1.5955 ± 0.000970073
# logging: k steps 4 -> -1.5955 ± 0.00114492
# logging: k steps 5 -> -1.5955 ± 0.00130392
# 30 0.4625 ---magnetization error:
# logging: k steps 1 -> 0.824632 ± 0.000771732
# logging: k steps 2 -> 0.824632 ± 0.00104319
# logging: k steps 3 -> 0.824632 ± 0.00139096
# logging: k steps 4 -> 0.824632 ± 0.00182555
# logging: k steps 5 -> 0.824632 ± 0.00231841
# 30 0.4625 --- C error:
# logging: correl lenght 8 -> 3.12333e-07 ± 5.63268e-09
# logging: correl lenght 16 -> 3.12348e-07 ± 7.24009e-09
# logging: correl lenght 32 -> 3.13196e-07 ± 8.36473e-09
# logging: correl lenght 64 -> 3.14349e-07 ± 1.05282e-08
# logging: correl lenght 128 -> 3.12053e-07 ± 9.94691e-09
# 30 0.4625 --- Ki error:
# logging: correl lenght 8 -> 3.20117e-07 ± 2.71701e-08
# logging: correl lenght 16 -> 3.27019e-07 ± 4.51521e-08
# logging: correl lenght 32 -> 3.17558e-07 ± 5.42266e-08
# logging: correl lenght 64 -> 3.17312e-07 ± 5.84875e-08
# logging: correl lenght 128 -> 3.16994e-07 ± 7.53587e-08
# 30 0.465 ---energy error:
# logging: k steps 1 -> -1.60728 ± 0.000660859
# logging: k steps 2 -> -1.60728 ± 0.000796162
# logging: k steps 3 -> -1.60728 ± 0.000947767
# logging: k steps 4 -> -1.60728 ± 0.00110609
# logging: k steps 5 -> -1.60728 ± 0.00128861
# 30 0.465 ---magnetization error:
# logging: k steps 1 -> 0.830657 ± 0.000806671
# logging: k steps 2 -> 0.830657 ± 0.00109741
# logging: k steps 3 -> 0.830657 ± 0.00147967
# logging: k steps 4 -> 0.830657 ± 0.0019633
# logging: k steps 5 -> 0.830657 ± 0.00256525
# 30 0.465 --- C error:
# logging: correl lenght 8 -> 3.00509e-07 ± 5.59428e-09
# logging: correl lenght 16 -> 2.99812e-07 ± 6.59551e-09
# logging: correl lenght 32 -> 3.0089e-07 ± 8.88232e-09
# logging: correl lenght 64 -> 3.02613e-07 ± 1.02319e-08
# logging: correl lenght 128 -> 2.99951e-07 ± 1.21991e-08
# 30 0.465 --- Ki error:
# logging: correl lenght 8 -> 3.46119e-07 ± 3.56123e-08
# logging: correl lenght 16 -> 3.43747e-07 ± 5.12706e-08
# logging: correl lenght 32 -> 3.53252e-07 ± 7.29627e-08
# logging: correl lenght 64 -> 3.43827e-07 ± 8.47265e-08
# logging: correl lenght 128 -> 3.63348e-07 ± 1.23233e-07
# 30 0.4675 ---energy error:
# logging: k steps 1 -> -1.62301 ± 0.00062979
# logging: k steps 2 -> -1.62301 ± 0.000749921
# logging: k steps 3 -> -1.62301 ± 0.000874428
# logging: k steps 4 -> -1.62301 ± 0.000981615
# logging: k steps 5 -> -1.62301 ± 0.0010438
# 30 0.4675 ---magnetization error:
# logging: k steps 1 -> 0.845362 ± 0.000544466
# logging: k steps 2 -> 0.845362 ± 0.000711927
# logging: k steps 3 -> 0.845362 ± 0.000898769
# logging: k steps 4 -> 0.845362 ± 0.0010887
# logging: k steps 5 -> 0.845362 ± 0.00121146
# 30 0.4675 --- C error:
# logging: correl lenght 8 -> 2.78919e-07 ± 3.77591e-09
# logging: correl lenght 16 -> 2.78943e-07 ± 4.57089e-09
# logging: correl lenght 32 -> 2.7845e-07 ± 4.7822e-09
# logging: correl lenght 64 -> 2.78962e-07 ± 4.5075e-09
# logging: correl lenght 128 -> 2.78126e-07 ± 5.41771e-09
# 30 0.4675 --- Ki error:
# logging: correl lenght 8 -> 1.70721e-07 ± 8.97368e-09
# logging: correl lenght 16 -> 1.68572e-07 ± 1.05649e-08
# logging: correl lenght 32 -> 1.68102e-07 ± 1.16909e-08
# logging: correl lenght 64 -> 1.70605e-07 ± 1.20937e-08
# logging: correl lenght 128 -> 1.68193e-07 ± 1.24047e-08
# 30 0.47 ---energy error:
# logging: k steps 1 -> -1.63479 ± 0.00060029
# logging: k steps 2 -> -1.63479 ± 0.000700221
# logging: k steps 3 -> -1.63479 ± 0.000799075
# logging: k steps 4 -> -1.63479 ± 0.000908052
# logging: k steps 5 -> -1.63479 ± 0.000989236
# 30 0.47 ---magnetization error:
# logging: k steps 1 -> 0.853128 ± 0.000490234
# logging: k steps 2 -> 0.853128 ± 0.000632089
# logging: k steps 3 -> 0.853128 ± 0.000787299
# logging: k steps 4 -> 0.853128 ± 0.000966771
# logging: k steps 5 -> 0.853128 ± 0.00112069
# 30 0.47 --- C error:
# logging: correl lenght 8 -> 2.60284e-07 ± 3.05983e-09
# logging: correl lenght 16 -> 2.59871e-07 ± 3.56859e-09
# logging: correl lenght 32 -> 2.59803e-07 ± 3.97243e-09
# logging: correl lenght 64 -> 2.6015e-07 ± 4.01583e-09
# logging: correl lenght 128 -> 2.59914e-07 ± 3.94588e-09
# 30 0.47 --- Ki error:
# logging: correl lenght 8 -> 1.40568e-07 ± 6.79633e-09
# logging: correl lenght 16 -> 1.39727e-07 ± 7.55947e-09
# logging: correl lenght 32 -> 1.4094e-07 ± 9.1186e-09
# logging: correl lenght 64 -> 1.40169e-07 ± 1.13445e-08
# logging: correl lenght 128 -> 1.42697e-07 ± 1.19434e-08
# 30 0.4725 ---energy error:
# logging: k steps 1 -> -1.64659 ± 0.000577123
# logging: k steps 2 -> -1.64659 ± 0.000667647
# logging: k steps 3 -> -1.64659 ± 0.000752446
# logging: k steps 4 -> -1.64659 ± 0.000834825
# logging: k steps 5 -> -1.64659 ± 0.000878232
# 30 0.4725 ---magnetization error:
# logging: k steps 1 -> 0.860268 ± 0.000447782
# logging: k steps 2 -> 0.860268 ± 0.000569801
# logging: k steps 3 -> 0.860268 ± 0.000702768
# logging: k steps 4 -> 0.860268 ± 0.00083266
# logging: k steps 5 -> 0.860268 ± 0.000929972
# 30 0.4725 --- C error:
# logging: correl lenght 8 -> 2.44111e-07 ± 3.25843e-09
# logging: correl lenght 16 -> 2.4377e-07 ± 3.24257e-09
# logging: correl lenght 32 -> 2.43964e-07 ± 3.23556e-09
# logging: correl lenght 64 -> 2.44081e-07 ± 3.99122e-09
# logging: correl lenght 128 -> 2.43902e-07 ± 4.05917e-09
# 30 0.4725 --- Ki error:
# logging: correl lenght 8 -> 1.19372e-07 ± 6.04667e-09
# logging: correl lenght 16 -> 1.19555e-07 ± 6.7229e-09
# logging: correl lenght 32 -> 1.19152e-07 ± 7.06465e-09
# logging: correl lenght 64 -> 1.19835e-07 ± 8.76273e-09
# logging: correl lenght 128 -> 1.19053e-07 ± 8.29692e-09
# 30 0.475 ---energy error:
# logging: k steps 1 -> -1.65729 ± 0.000571344
# logging: k steps 2 -> -1.65729 ± 0.000661184
# logging: k steps 3 -> -1.65729 ± 0.000753979
# logging: k steps 4 -> -1.65729 ± 0.000837576
# logging: k steps 5 -> -1.65729 ± 0.000883186
# 30 0.475 ---magnetization error:
# logging: k steps 1 -> 0.866285 ± 0.000421423
# logging: k steps 2 -> 0.866285 ± 0.000534533
# logging: k steps 3 -> 0.866285 ± 0.000651071
# logging: k steps 4 -> 0.866285 ± 0.000761975
# logging: k steps 5 -> 0.866285 ± 0.000819793
# 30 0.475 --- C error:
# logging: correl lenght 8 -> 2.38959e-07 ± 3.64418e-09
# logging: correl lenght 16 -> 2.38999e-07 ± 3.59496e-09
# logging: correl lenght 32 -> 2.39282e-07 ± 3.75377e-09
# logging: correl lenght 64 -> 2.39727e-07 ± 4.28981e-09
# logging: correl lenght 128 -> 2.39505e-07 ± 3.7177e-09
# 30 0.475 --- Ki error:
# logging: correl lenght 8 -> 1.07969e-07 ± 3.59231e-09
# logging: correl lenght 16 -> 1.07674e-07 ± 4.62922e-09
# logging: correl lenght 32 -> 1.07173e-07 ± 4.41964e-09
# logging: correl lenght 64 -> 1.06981e-07 ± 5.7732e-09
# logging: correl lenght 128 -> 1.06336e-07 ± 4.85083e-09
# 30 0.4775 ---energy error:
# logging: k steps 1 -> -1.6673 ± 0.000554744
# logging: k steps 2 -> -1.6673 ± 0.00063726
# logging: k steps 3 -> -1.6673 ± 0.000714011
# logging: k steps 4 -> -1.6673 ± 0.000778851
# logging: k steps 5 -> -1.6673 ± 0.00075914
# 30 0.4775 ---magnetization error:
# logging: k steps 1 -> 0.871875 ± 0.000400687
# logging: k steps 2 -> 0.871875 ± 0.000503613
# logging: k steps 3 -> 0.871875 ± 0.000610337
# logging: k steps 4 -> 0.871875 ± 0.000714921
# logging: k steps 5 -> 0.871875 ± 0.000728997
# 30 0.4775 --- C error:
# logging: correl lenght 8 -> 2.28548e-07 ± 3.23805e-09
# logging: correl lenght 16 -> 2.28391e-07 ± 3.14161e-09
# logging: correl lenght 32 -> 2.28786e-07 ± 3.28336e-09
# logging: correl lenght 64 -> 2.28792e-07 ± 3.44818e-09
# logging: correl lenght 128 -> 2.28932e-07 ± 3.36556e-09
# 30 0.4775 --- Ki error:
# logging: correl lenght 8 -> 9.77595e-08 ± 4.15659e-09
# logging: correl lenght 16 -> 9.78771e-08 ± 4.88856e-09
# logging: correl lenght 32 -> 9.81389e-08 ± 5.42987e-09
# logging: correl lenght 64 -> 9.84456e-08 ± 5.69163e-09
# logging: correl lenght 128 -> 9.93096e-08 ± 7.06234e-09
# 30 0.48 ---energy error:
# logging: k steps 1 -> -1.67792 ± 0.000536164
# logging: k steps 2 -> -1.67792 ± 0.000610276
# logging: k steps 3 -> -1.67792 ± 0.000680557
# logging: k steps 4 -> -1.67792 ± 0.000750074
# logging: k steps 5 -> -1.67792 ± 0.000779315
# 30 0.48 ---magnetization error:
# logging: k steps 1 -> 0.877545 ± 0.000374078
# logging: k steps 2 -> 0.877545 ± 0.000466379
# logging: k steps 3 -> 0.877545 ± 0.000560462
# logging: k steps 4 -> 0.877545 ± 0.00064904
# logging: k steps 5 -> 0.877545 ± 0.000691049
# 30 0.48 --- C error:
# logging: correl lenght 8 -> 2.18092e-07 ± 2.85155e-09
# logging: correl lenght 16 -> 2.17806e-07 ± 2.55985e-09
# logging: correl lenght 32 -> 2.18626e-07 ± 2.62797e-09
# logging: correl lenght 64 -> 2.1789e-07 ± 3.02036e-09
# logging: correl lenght 128 -> 2.18033e-07 ± 2.94073e-09
# 30 0.48 --- Ki error:
# logging: correl lenght 8 -> 8.73487e-08 ± 3.112e-09
# logging: correl lenght 16 -> 8.70989e-08 ± 3.54969e-09
# logging: correl lenght 32 -> 8.66015e-08 ± 3.87674e-09
# logging: correl lenght 64 -> 8.71482e-08 ± 4.01344e-09
# logging: correl lenght 128 -> 8.67955e-08 ± 4.00494e-09
# 30 0.4825 ---energy error:
# logging: k steps 1 -> -1.68827 ± 0.000526273
# logging: k steps 2 -> -1.68827 ± 0.000594014
# logging: k steps 3 -> -1.68827 ± 0.00066457
# logging: k steps 4 -> -1.68827 ± 0.000724205
# logging: k steps 5 -> -1.68827 ± 0.000767055
# 30 0.4825 ---magnetization error:
# logging: k steps 1 -> 0.882958 ± 0.000375114
# logging: k steps 2 -> 0.882958 ± 0.000474039
# logging: k steps 3 -> 0.882958 ± 0.000583564
# logging: k steps 4 -> 0.882958 ± 0.00069759
# logging: k steps 5 -> 0.882958 ± 0.000767225
# 30 0.4825 --- C error:
# logging: correl lenght 8 -> 2.113e-07 ± 2.85564e-09
# logging: correl lenght 16 -> 2.10926e-07 ± 2.55995e-09
# logging: correl lenght 32 -> 2.11522e-07 ± 3.21552e-09
# logging: correl lenght 64 -> 2.11209e-07 ± 3.20524e-09
# logging: correl lenght 128 -> 2.10539e-07 ± 3.17956e-09
# 30 0.4825 --- Ki error:
# logging: correl lenght 8 -> 8.59113e-08 ± 3.93601e-09
# logging: correl lenght 16 -> 8.68124e-08 ± 5.33886e-09
# logging: correl lenght 32 -> 8.65368e-08 ± 5.50807e-09
# logging: correl lenght 64 -> 8.62305e-08 ± 6.99373e-09
# logging: correl lenght 128 -> 8.71215e-08 ± 7.39727e-09
# 30 0.485 ---energy error:
# logging: k steps 1 -> -1.6967 ± 0.00051601
# logging: k steps 2 -> -1.6967 ± 0.000579537
# logging: k steps 3 -> -1.6967 ± 0.000646665
# logging: k steps 4 -> -1.6967 ± 0.000699148
# logging: k steps 5 -> -1.6967 ± 0.000741961
# 30 0.485 ---magnetization error:
# logging: k steps 1 -> 0.887433 ± 0.000339541
# logging: k steps 2 -> 0.887433 ± 0.000419981
# logging: k steps 3 -> 0.887433 ± 0.0005036
# logging: k steps 4 -> 0.887433 ± 0.000579597
# logging: k steps 5 -> 0.887433 ± 0.000633749
# 30 0.485 --- C error:
# logging: correl lenght 8 -> 2.03502e-07 ± 2.63177e-09
# logging: correl lenght 16 -> 2.03636e-07 ± 2.77488e-09
# logging: correl lenght 32 -> 2.04362e-07 ± 2.67583e-09
# logging: correl lenght 64 -> 2.03066e-07 ± 2.54212e-09
# logging: correl lenght 128 -> 2.0329e-07 ± 2.61391e-09
# 30 0.485 --- Ki error:
# logging: correl lenght 8 -> 7.34514e-08 ± 2.81312e-09
# logging: correl lenght 16 -> 7.36212e-08 ± 3.04457e-09
# logging: correl lenght 32 -> 7.31558e-08 ± 3.27923e-09
# logging: correl lenght 64 -> 7.27508e-08 ± 3.38852e-09
# logging: correl lenght 128 -> 7.30379e-08 ± 3.16321e-09
# 30 0.4875 ---energy error:
# logging: k steps 1 -> -1.70555 ± 0.00049991
# logging: k steps 2 -> -1.70555 ± 0.000566002
# logging: k steps 3 -> -1.70555 ± 0.000616405
# logging: k steps 4 -> -1.70555 ± 0.000647511
# logging: k steps 5 -> -1.70555 ± 0.000657606
# 30 0.4875 ---magnetization error:
# logging: k steps 1 -> 0.892436 ± 0.000311693
# logging: k steps 2 -> 0.892436 ± 0.000381266
# logging: k steps 3 -> 0.892436 ± 0.00044207
# logging: k steps 4 -> 0.892436 ± 0.000490669
# logging: k steps 5 -> 0.892436 ± 0.000520632
# 30 0.4875 --- C error:
# logging: correl lenght 8 -> 1.92996e-07 ± 2.28404e-09
# logging: correl lenght 16 -> 1.92673e-07 ± 2.57133e-09
# logging: correl lenght 32 -> 1.92568e-07 ± 2.48945e-09
# logging: correl lenght 64 -> 1.92777e-07 ± 2.54748e-09
# logging: correl lenght 128 -> 1.93167e-07 ± 2.5345e-09
# 30 0.4875 --- Ki error:
# logging: correl lenght 8 -> 6.29875e-08 ± 2.1095e-09
# logging: correl lenght 16 -> 6.28218e-08 ± 2.25178e-09
# logging: correl lenght 32 -> 6.29894e-08 ± 2.0415e-09
# logging: correl lenght 64 -> 6.28788e-08 ± 2.53496e-09
# logging: correl lenght 128 -> 6.30249e-08 ± 2.82028e-09
# 30 0.49 ---energy error:
# logging: k steps 1 -> -1.71426 ± 0.000493482
# logging: k steps 2 -> -1.71426 ± 0.000550239
# logging: k steps 3 -> -1.71426 ± 0.000596539
# logging: k steps 4 -> -1.71426 ± 0.000644681
# logging: k steps 5 -> -1.71426 ± 0.000669976
# 30 0.49 ---magnetization error:
# logging: k steps 1 -> 0.896667 ± 0.000297944
# logging: k steps 2 -> 0.896667 ± 0.000358743
# logging: k steps 3 -> 0.896667 ± 0.000416427
# logging: k steps 4 -> 0.896667 ± 0.000465901
# logging: k steps 5 -> 0.896667 ± 0.000491201
# 30 0.49 --- C error:
# logging: correl lenght 8 -> 1.89715e-07 ± 2.2878e-09
# logging: correl lenght 16 -> 1.89233e-07 ± 2.0856e-09
# logging: correl lenght 32 -> 1.89632e-07 ± 2.45433e-09
# logging: correl lenght 64 -> 1.90086e-07 ± 2.70689e-09
# logging: correl lenght 128 -> 1.89533e-07 ± 2.33915e-09
# 30 0.49 --- Ki error:
# logging: correl lenght 8 -> 5.86599e-08 ± 1.6667e-09
# logging: correl lenght 16 -> 5.85669e-08 ± 1.9225e-09
# logging: correl lenght 32 -> 5.84318e-08 ± 1.91688e-09
# logging: correl lenght 64 -> 5.87994e-08 ± 1.99496e-09
# logging: correl lenght 128 -> 5.88319e-08 ± 2.25727e-09
# 30 0.4925 ---energy error:
# logging: k steps 1 -> -1.72259 ± 0.000485037
# logging: k steps 2 -> -1.72259 ± 0.000549209
# logging: k steps 3 -> -1.72259 ± 0.000598818
# logging: k steps 4 -> -1.72259 ± 0.000641183
# logging: k steps 5 -> -1.72259 ± 0.000649782
# 30 0.4925 ---magnetization error:
# logging: k steps 1 -> 0.900138 ± 0.000308493
# logging: k steps 2 -> 0.900138 ± 0.000383984
# logging: k steps 3 -> 0.900138 ± 0.000458608
# logging: k steps 4 -> 0.900138 ± 0.000521696
# logging: k steps 5 -> 0.900138 ± 0.000570109
# 30 0.4925 --- C error:
# logging: correl lenght 8 -> 1.83192e-07 ± 2.36093e-09
# logging: correl lenght 16 -> 1.82889e-07 ± 2.30737e-09
# logging: correl lenght 32 -> 1.83658e-07 ± 2.73691e-09
# logging: correl lenght 64 -> 1.82698e-07 ± 2.94609e-09
# logging: correl lenght 128 -> 1.82719e-07 ± 2.56649e-09
# 30 0.4925 --- Ki error:
# logging: correl lenght 8 -> 6.05355e-08 ± 2.88709e-09
# logging: correl lenght 16 -> 6.03167e-08 ± 3.77917e-09
# logging: correl lenght 32 -> 6.00706e-08 ± 4.00017e-09
# logging: correl lenght 64 -> 6.05468e-08 ± 4.1177e-09
# logging: correl lenght 128 -> 6.07153e-08 ± 3.70396e-09
# 30 0.495 ---energy error:
# logging: k steps 1 -> -1.73115 ± 0.000467393
# logging: k steps 2 -> -1.73115 ± 0.000523088
# logging: k steps 3 -> -1.73115 ± 0.000564447
# logging: k steps 4 -> -1.73115 ± 0.000598581
# logging: k steps 5 -> -1.73115 ± 0.000605573
# 30 0.495 ---magnetization error:
# logging: k steps 1 -> 0.904869 ± 0.000265777
# logging: k steps 2 -> 0.904869 ± 0.000316769
# logging: k steps 3 -> 0.904869 ± 0.000361229
# logging: k steps 4 -> 0.904869 ± 0.000395295
# logging: k steps 5 -> 0.904869 ± 0.000406443
# 30 0.495 --- C error:
# logging: correl lenght 8 -> 1.70769e-07 ± 1.90388e-09
# logging: correl lenght 16 -> 1.7111e-07 ± 1.95281e-09
# logging: correl lenght 32 -> 1.71148e-07 ± 2.01035e-09
# logging: correl lenght 64 -> 1.71223e-07 ± 2.17376e-09
# logging: correl lenght 128 -> 1.70922e-07 ± 1.87092e-09
# 30 0.495 --- Ki error:
# logging: correl lenght 8 -> 4.75474e-08 ± 1.0282e-09
# logging: correl lenght 16 -> 4.73616e-08 ± 1.20996e-09
# logging: correl lenght 32 -> 4.74113e-08 ± 1.24386e-09
# logging: correl lenght 64 -> 4.73851e-08 ± 1.382e-09
# logging: correl lenght 128 -> 4.75209e-08 ± 1.23364e-09
# 30 0.4975 ---energy error:
# logging: k steps 1 -> -1.73865 ± 0.000453127
# logging: k steps 2 -> -1.73865 ± 0.000494218
# logging: k steps 3 -> -1.73865 ± 0.000520872
# logging: k steps 4 -> -1.73865 ± 0.000547913
# logging: k steps 5 -> -1.73865 ± 0.00055831
# 30 0.4975 ---magnetization error:
# logging: k steps 1 -> 0.908651 ± 0.000247005
# logging: k steps 2 -> 0.908651 ± 0.000287773
# logging: k steps 3 -> 0.908651 ± 0.000318933
# logging: k steps 4 -> 0.908651 ± 0.000344636
# logging: k steps 5 -> 0.908651 ± 0.000351921
# 30 0.4975 --- C error:
# logging: correl lenght 8 -> 1.64248e-07 ± 1.99997e-09
# logging: correl lenght 16 -> 1.64257e-07 ± 1.83021e-09
# logging: correl lenght 32 -> 1.63786e-07 ± 1.97744e-09
# logging: correl lenght 64 -> 1.642e-07 ± 1.83864e-09
# logging: correl lenght 128 -> 1.64022e-07 ± 1.88323e-09
# 30 0.4975 --- Ki error:
# logging: correl lenght 8 -> 4.22232e-08 ± 8.6247e-10
# logging: correl lenght 16 -> 4.24922e-08 ± 1.00292e-09
# logging: correl lenght 32 -> 4.24368e-08 ± 1.01383e-09
# logging: correl lenght 64 -> 4.25044e-08 ± 1.10917e-09
# logging: correl lenght 128 -> 4.25287e-08 ± 1.07382e-09
# 30 0.5 ---energy error:
# logging: k steps 1 -> -1.7453 ± 0.000450199
# logging: k steps 2 -> -1.7453 ± 0.000495487
# logging: k steps 3 -> -1.7453 ± 0.00053004
# logging: k steps 4 -> -1.7453 ± 0.000564237
# logging: k steps 5 -> -1.7453 ± 0.000604457
# 30 0.5 ---magnetization error:
# logging: k steps 1 -> 0.911073 ± 0.000254408
# logging: k steps 2 -> 0.911073 ± 0.00030228
# logging: k steps 3 -> 0.911073 ± 0.000348435
# logging: k steps 4 -> 0.911073 ± 0.000388965
# logging: k steps 5 -> 0.911073 ± 0.000427067
# 30 0.5 --- C error:
# logging: correl lenght 8 -> 1.61471e-07 ± 1.94596e-09
# logging: correl lenght 16 -> 1.61254e-07 ± 2.04392e-09
# logging: correl lenght 32 -> 1.61549e-07 ± 2.21563e-09
# logging: correl lenght 64 -> 1.61308e-07 ± 1.93223e-09
# logging: correl lenght 128 -> 1.61225e-07 ± 2.05285e-09
# 30 0.5 --- Ki error:
# logging: correl lenght 8 -> 4.36658e-08 ± 1.68526e-09
# logging: correl lenght 16 -> 4.36802e-08 ± 1.7429e-09
# logging: correl lenght 32 -> 4.34617e-08 ± 1.85153e-09
# logging: correl lenght 64 -> 4.34907e-08 ± 2.34534e-09
# logging: correl lenght 128 -> 4.33129e-08 ± 2.14209e-09
# 30 0.5025 ---energy error:
# logging: k steps 1 -> -1.75268 ± 0.000443711
# logging: k steps 2 -> -1.75268 ± 0.000486343
# logging: k steps 3 -> -1.75268 ± 0.000521001
# logging: k steps 4 -> -1.75268 ± 0.000552565
# logging: k steps 5 -> -1.75268 ± 0.000566345
# 30 0.5025 ---magnetization error:
# logging: k steps 1 -> 0.9144 ± 0.000241938
# logging: k steps 2 -> 0.9144 ± 0.000283985
# logging: k steps 3 -> 0.9144 ± 0.00032113
# logging: k steps 4 -> 0.9144 ± 0.000348846
# logging: k steps 5 -> 0.9144 ± 0.000368687
# 30 0.5025 --- C error:
# logging: correl lenght 8 -> 1.57647e-07 ± 1.998e-09
# logging: correl lenght 16 -> 1.57391e-07 ± 1.96659e-09
# logging: correl lenght 32 -> 1.57518e-07 ± 2.16256e-09
# logging: correl lenght 64 -> 1.57405e-07 ± 1.93045e-09
# logging: correl lenght 128 -> 1.57664e-07 ± 2.00966e-09
# 30 0.5025 --- Ki error:
# logging: correl lenght 8 -> 4.02983e-08 ± 1.18613e-09
# logging: correl lenght 16 -> 4.0317e-08 ± 1.33237e-09
# logging: correl lenght 32 -> 4.03275e-08 ± 1.21531e-09
# logging: correl lenght 64 -> 4.01745e-08 ± 1.41036e-09
# logging: correl lenght 128 -> 4.03992e-08 ± 1.43418e-09
# 30 0.505 ---energy error:
# logging: k steps 1 -> -1.7593 ± 0.000426601
# logging: k steps 2 -> -1.7593 ± 0.000461769
# logging: k steps 3 -> -1.7593 ± 0.000487454
# logging: k steps 4 -> -1.7593 ± 0.000504524
# logging: k steps 5 -> -1.7593 ± 0.000519017
# 30 0.505 ---magnetization error:
# logging: k steps 1 -> 0.917623 ± 0.000221241
# logging: k steps 2 -> 0.917623 ± 0.000255108
# logging: k steps 3 -> 0.917623 ± 0.000282539
# logging: k steps 4 -> 0.917623 ± 0.000301133
# logging: k steps 5 -> 0.917623 ± 0.000308558
# 30 0.505 --- C error:
# logging: correl lenght 8 -> 1.49524e-07 ± 1.52503e-09
# logging: correl lenght 16 -> 1.49047e-07 ± 1.68662e-09
# logging: correl lenght 32 -> 1.48984e-07 ± 1.59407e-09
# logging: correl lenght 64 -> 1.48968e-07 ± 1.75393e-09
# logging: correl lenght 128 -> 1.49389e-07 ± 1.92318e-09
# 30 0.505 --- Ki error:
# logging: correl lenght 8 -> 3.51051e-08 ± 7.17292e-10
# logging: correl lenght 16 -> 3.51326e-08 ± 6.83645e-10
# logging: correl lenght 32 -> 3.50022e-08 ± 7.38727e-10
# logging: correl lenght 64 -> 3.48934e-08 ± 8.98644e-10
# logging: correl lenght 128 -> 3.49054e-08 ± 8.6368e-10
# 30 0.5075 ---energy error:
# logging: k steps 1 -> -1.76498 ± 0.00042284
# logging: k steps 2 -> -1.76498 ± 0.000463439
# logging: k steps 3 -> -1.76498 ± 0.000500083
# logging: k steps 4 -> -1.76498 ± 0.000522092
# logging: k steps 5 -> -1.76498 ± 0.000533906
# 30 0.5075 ---magnetization error:
# logging: k steps 1 -> 0.919912 ± 0.000222561
# logging: k steps 2 -> 0.919912 ± 0.000261679
# logging: k steps 3 -> 0.919912 ± 0.000298901
# logging: k steps 4 -> 0.919912 ± 0.000320468
# logging: k steps 5 -> 0.919912 ± 0.000323029
# 30 0.5075 --- C error:
# logging: correl lenght 8 -> 1.47139e-07 ± 1.76506e-09
# logging: correl lenght 16 -> 1.46601e-07 ± 1.8372e-09
# logging: correl lenght 32 -> 1.47296e-07 ± 1.77528e-09
# logging: correl lenght 64 -> 1.46698e-07 ± 1.91816e-09
# logging: correl lenght 128 -> 1.47153e-07 ± 1.73001e-09
# 30 0.5075 --- Ki error:
# logging: correl lenght 8 -> 3.50099e-08 ± 1.01027e-09
# logging: correl lenght 16 -> 3.514e-08 ± 1.03659e-09
# logging: correl lenght 32 -> 3.51249e-08 ± 1.08087e-09
# logging: correl lenght 64 -> 3.51827e-08 ± 1.31149e-09
# logging: correl lenght 128 -> 3.50515e-08 ± 1.06132e-09
# 30 0.51 ---energy error:
# logging: k steps 1 -> -1.77297 ± 0.000414181
# logging: k steps 2 -> -1.77297 ± 0.000446397
# logging: k steps 3 -> -1.77297 ± 0.000468165
# logging: k steps 4 -> -1.77297 ± 0.000481404
# logging: k steps 5 -> -1.77297 ± 0.000484316
# 30 0.51 ---magnetization error:
# logging: k steps 1 -> 0.923309 ± 0.000212146
# logging: k steps 2 -> 0.923309 ± 0.0002442
# logging: k steps 3 -> 0.923309 ± 0.000267451
# logging: k steps 4 -> 0.923309 ± 0.000281574
# logging: k steps 5 -> 0.923309 ± 0.000283712
# 30 0.51 --- C error:
# logging: correl lenght 8 -> 1.39312e-07 ± 1.51211e-09
# logging: correl lenght 16 -> 1.39623e-07 ± 1.50121e-09
# logging: correl lenght 32 -> 1.39758e-07 ± 1.66663e-09
# logging: correl lenght 64 -> 1.39363e-07 ± 1.60376e-09
# logging: correl lenght 128 -> 1.393e-07 ± 1.56947e-09
# 30 0.51 --- Ki error:
# logging: correl lenght 8 -> 3.20141e-08 ± 7.34674e-10
# logging: correl lenght 16 -> 3.19049e-08 ± 7.72801e-10
# logging: correl lenght 32 -> 3.18274e-08 ± 8.79794e-10
# logging: correl lenght 64 -> 3.1855e-08 ± 7.63142e-10
# logging: correl lenght 128 -> 3.20078e-08 ± 6.99857e-10
#
# Creating file: Side_40/averages_and_variance.dat
# 40 0.36 ---energy error:
# logging: k steps 1 -> -0.920563 ± 0.000388135
# logging: k steps 2 -> -0.920563 ± 0.000420499
# logging: k steps 3 -> -0.920563 ± 0.00043967
# logging: k steps 4 -> -0.920563 ± 0.000453905
# logging: k steps 5 -> -0.920563 ± 0.000468046
# 40 0.36 ---magnetization error:
# logging: k steps 1 -> 0.0882171 ± 0.000595082
# logging: k steps 2 -> 0.0882171 ± 0.000738253
# logging: k steps 3 -> 0.0882171 ± 0.000858386
# logging: k steps 4 -> 0.0882171 ± 0.000931959
# logging: k steps 5 -> 0.0882171 ± 0.00094744
# 40 0.36 --- C error:
# logging: correl lenght 8 -> 1.27202e-07 ± 1.35297e-09
# logging: correl lenght 16 -> 1.26972e-07 ± 1.18077e-09
# logging: correl lenght 32 -> 1.27e-07 ± 1.18603e-09
# logging: correl lenght 64 -> 1.27075e-07 ± 1.30106e-09
# logging: correl lenght 128 -> 1.26918e-07 ± 1.28667e-09
# 40 0.36 --- Ki error:
# logging: correl lenght 8 -> 2.18533e-07 ± 4.45984e-09
# logging: correl lenght 16 -> 2.18397e-07 ± 4.47666e-09
# logging: correl lenght 32 -> 2.18404e-07 ± 5.4498e-09
# logging: correl lenght 64 -> 2.19028e-07 ± 4.79201e-09
# logging: correl lenght 128 -> 2.19241e-07 ± 5.00341e-09
# 40 0.3625 ---energy error:
# logging: k steps 1 -> -0.930982 ± 0.000393862
# logging: k steps 2 -> -0.930982 ± 0.000427255
# logging: k steps 3 -> -0.930982 ± 0.000445705
# logging: k steps 4 -> -0.930982 ± 0.000460946
# logging: k steps 5 -> -0.930982 ± 0.000474077
# 40 0.3625 ---magnetization error:
# logging: k steps 1 -> 0.0912931 ± 0.00061286
# logging: k steps 2 -> 0.0912931 ± 0.000763305
# logging: k steps 3 -> 0.0912931 ± 0.000900997
# logging: k steps 4 -> 0.0912931 ± 0.000968541
# logging: k steps 5 -> 0.0912931 ± 0.00101574
# 40 0.3625 --- C error:
# logging: correl lenght 8 -> 1.29441e-07 ± 1.21974e-09
# logging: correl lenght 16 -> 1.29592e-07 ± 1.45585e-09
# logging: correl lenght 32 -> 1.29472e-07 ± 1.3911e-09
# logging: correl lenght 64 -> 1.29298e-07 ± 1.17699e-09
# logging: correl lenght 128 -> 1.29325e-07 ± 1.16648e-09
# 40 0.3625 --- Ki error:
# logging: correl lenght 8 -> 2.28218e-07 ± 4.8947e-09
# logging: correl lenght 16 -> 2.2789e-07 ± 5.46345e-09
# logging: correl lenght 32 -> 2.27615e-07 ± 5.59199e-09
# logging: correl lenght 64 -> 2.28321e-07 ± 5.36473e-09
# logging: correl lenght 128 -> 2.28058e-07 ± 4.95627e-09
# 40 0.365 ---energy error:
# logging: k steps 1 -> -0.941023 ± 0.000400458
# logging: k steps 2 -> -0.941023 ± 0.000433931
# logging: k steps 3 -> -0.941023 ± 0.000461977
# logging: k steps 4 -> -0.941023 ± 0.000476975
# logging: k steps 5 -> -0.941023 ± 0.000481287
# 40 0.365 ---magnetization error:
# logging: k steps 1 -> 0.0930653 ± 0.00062545
# logging: k steps 2 -> 0.0930652 ± 0.000779534
# logging: k steps 3 -> 0.0930652 ± 0.000922159
# logging: k steps 4 -> 0.0930653 ± 0.00101876
# logging: k steps 5 -> 0.0930653 ± 0.00108408
# 40 0.365 --- C error:
# logging: correl lenght 8 -> 1.3214e-07 ± 1.59613e-09
# logging: correl lenght 16 -> 1.32106e-07 ± 1.23848e-09
# logging: correl lenght 32 -> 1.31974e-07 ± 1.28254e-09
# logging: correl lenght 64 -> 1.32103e-07 ± 1.36274e-09
# logging: correl lenght 128 -> 1.31938e-07 ± 1.42852e-09
# 40 0.365 --- Ki error:
# logging: correl lenght 8 -> 2.36456e-07 ± 4.87895e-09
# logging: correl lenght 16 -> 2.36923e-07 ± 4.50152e-09
# logging: correl lenght 32 -> 2.37373e-07 ± 5.69523e-09
# logging: correl lenght 64 -> 2.36216e-07 ± 5.38872e-09
# logging: correl lenght 128 -> 2.35577e-07 ± 5.49472e-09
# 40 0.3675 ---energy error:
# logging: k steps 1 -> -0.952478 ± 0.000407339
# logging: k steps 2 -> -0.952478 ± 0.000448849
# logging: k steps 3 -> -0.952478 ± 0.000481317
# logging: k steps 4 -> -0.952478 ± 0.000499246
# logging: k steps 5 -> -0.952478 ± 0.000506567
# 40 0.3675 ---magnetization error:
# logging: k steps 1 -> 0.0967796 ± 0.000666586
# logging: k steps 2 -> 0.0967796 ± 0.00083812
# logging: k steps 3 -> 0.0967796 ± 0.00099171
# logging: k steps 4 -> 0.0967796 ± 0.0010922
# logging: k steps 5 -> 0.0967796 ± 0.00111189
# 40 0.3675 --- C error:
# logging: correl lenght 8 -> 1.34616e-07 ± 1.38569e-09
# logging: correl lenght 16 -> 1.34623e-07 ± 1.66104e-09
# logging: correl lenght 32 -> 1.34507e-07 ± 1.36917e-09
# logging: correl lenght 64 -> 1.35021e-07 ± 1.27889e-09
# logging: correl lenght 128 -> 1.34784e-07 ± 1.31032e-09
# 40 0.3675 --- Ki error:
# logging: correl lenght 8 -> 2.64859e-07 ± 5.56676e-09
# logging: correl lenght 16 -> 2.63464e-07 ± 6.92306e-09
# logging: correl lenght 32 -> 2.64706e-07 ± 5.2536e-09
# logging: correl lenght 64 -> 2.62573e-07 ± 5.70149e-09
# logging: correl lenght 128 -> 2.64423e-07 ± 6.00869e-09
# 40 0.37 ---energy error:
# logging: k steps 1 -> -0.961533 ± 0.00040673
# logging: k steps 2 -> -0.961533 ± 0.00044376
# logging: k steps 3 -> -0.961533 ± 0.000477535
# logging: k steps 4 -> -0.961533 ± 0.000495413
# logging: k steps 5 -> -0.961533 ± 0.000516647
# 40 0.37 ---magnetization error:
# logging: k steps 1 -> 0.0989077 ± 0.000686445
# logging: k steps 2 -> 0.0989077 ± 0.000871179
# logging: k steps 3 -> 0.0989077 ± 0.00104839
# logging: k steps 4 -> 0.0989077 ± 0.00117864
# logging: k steps 5 -> 0.0989077 ± 0.00124569
# 40 0.37 --- C error:
# logging: correl lenght 8 -> 1.35869e-07 ± 1.49443e-09
# logging: correl lenght 16 -> 1.358e-07 ± 1.3911e-09
# logging: correl lenght 32 -> 1.35328e-07 ± 1.53507e-09
# logging: correl lenght 64 -> 1.35561e-07 ± 1.26736e-09
# logging: correl lenght 128 -> 1.35682e-07 ± 1.40249e-09
# 40 0.37 --- Ki error:
# logging: correl lenght 8 -> 2.77798e-07 ± 6.38214e-09
# logging: correl lenght 16 -> 2.77053e-07 ± 6.41643e-09
# logging: correl lenght 32 -> 2.76927e-07 ± 7.95782e-09
# logging: correl lenght 64 -> 2.76827e-07 ± 6.10734e-09
# logging: correl lenght 128 -> 2.78527e-07 ± 6.16353e-09
# 40 0.3725 ---energy error:
# logging: k steps 1 -> -0.972573 ± 0.000409177
# logging: k steps 2 -> -0.972573 ± 0.000450889
# logging: k steps 3 -> -0.972573 ± 0.00048223
# logging: k steps 4 -> -0.972573 ± 0.000514468
# logging: k steps 5 -> -0.972573 ± 0.000524852
# 40 0.3725 ---magnetization error:
# logging: k steps 1 -> 0.0991077 ± 0.000681781
# logging: k steps 2 -> 0.0991077 ± 0.000865702
# logging: k steps 3 -> 0.0991077 ± 0.00103948
# logging: k steps 4 -> 0.0991078 ± 0.00117307
# logging: k steps 5 -> 0.0991078 ± 0.00124924
# 40 0.3725 --- C error:
# logging: correl lenght 8 -> 1.35335e-07 ± 1.17534e-09
# logging: correl lenght 16 -> 1.3541e-07 ± 1.257e-09
# logging: correl lenght 32 -> 1.35172e-07 ± 1.65058e-09
# logging: correl lenght 64 -> 1.35452e-07 ± 1.36634e-09
# logging: correl lenght 128 -> 1.3555e-07 ± 1.57792e-09
# 40 0.3725 --- Ki error:
# logging: correl lenght 8 -> 2.74336e-07 ± 5.20848e-09
# logging: correl lenght 16 -> 2.74395e-07 ± 7.16495e-09
# logging: correl lenght 32 -> 2.75644e-07 ± 7.77261e-09
# logging: correl lenght 64 -> 2.7449e-07 ± 7.64605e-09
# logging: correl lenght 128 -> 2.73869e-07 ± 7.69513e-09
# 40 0.375 ---energy error:
# logging: k steps 1 -> -0.983847 ± 0.000420217
# logging: k steps 2 -> -0.983847 ± 0.00046633
# logging: k steps 3 -> -0.983847 ± 0.000510332
# logging: k steps 4 -> -0.983847 ± 0.000552123
# logging: k steps 5 -> -0.983847 ± 0.000570439
# 40 0.375 ---magnetization error:
# logging: k steps 1 -> 0.105311 ± 0.00073866
# logging: k steps 2 -> 0.105311 ± 0.000949229
# logging: k steps 3 -> 0.105311 ± 0.00115973
# logging: k steps 4 -> 0.105311 ± 0.00135112
# logging: k steps 5 -> 0.105311 ± 0.00144038
# 40 0.375 --- C error:
# logging: correl lenght 8 -> 1.39636e-07 ± 1.38743e-09
# logging: correl lenght 16 -> 1.39821e-07 ± 1.66532e-09
# logging: correl lenght 32 -> 1.39626e-07 ± 1.51879e-09
# logging: correl lenght 64 -> 1.39647e-07 ± 1.59335e-09
# logging: correl lenght 128 -> 1.39441e-07 ± 1.57423e-09
# 40 0.375 --- Ki error:
# logging: correl lenght 8 -> 3.13752e-07 ± 6.59576e-09
# logging: correl lenght 16 -> 3.13559e-07 ± 7.75535e-09
# logging: correl lenght 32 -> 3.13203e-07 ± 8.31834e-09
# logging: correl lenght 64 -> 3.12903e-07 ± 9.0718e-09
# logging: correl lenght 128 -> 3.14617e-07 ± 9.15738e-09
# 40 0.3775 ---energy error:
# logging: k steps 1 -> -0.995092 ± 0.000423367
# logging: k steps 2 -> -0.995092 ± 0.00046877
# logging: k steps 3 -> -0.995092 ± 0.000503038
# logging: k steps 4 -> -0.995092 ± 0.000524681
# logging: k steps 5 -> -0.995092 ± 0.000544779
# 40 0.3775 ---magnetization error:
# logging: k steps 1 -> 0.106641 ± 0.000733267
# logging: k steps 2 -> 0.106641 ± 0.000939009
# logging: k steps 3 -> 0.106641 ± 0.00114955
# logging: k steps 4 -> 0.106641 ± 0.00130909
# logging: k steps 5 -> 0.106641 ± 0.00140841
# 40 0.3775 --- C error:
# logging: correl lenght 8 -> 1.41003e-07 ± 1.45046e-09
# logging: correl lenght 16 -> 1.40933e-07 ± 1.62286e-09
# logging: correl lenght 32 -> 1.41011e-07 ± 1.49872e-09
# logging: correl lenght 64 -> 1.41001e-07 ± 1.47197e-09
# logging: correl lenght 128 -> 1.40847e-07 ± 1.49323e-09
# 40 0.3775 --- Ki error:
# logging: correl lenght 8 -> 3.10117e-07 ± 7.42315e-09
# logging: correl lenght 16 -> 3.1101e-07 ± 7.55592e-09
# logging: correl lenght 32 -> 3.10859e-07 ± 8.09548e-09
# logging: correl lenght 64 -> 3.10761e-07 ± 9.21196e-09
# logging: correl lenght 128 -> 3.08934e-07 ± 7.08999e-09
# 40 0.38 ---energy error:
# logging: k steps 1 -> -1.00627 ± 0.000427232
# logging: k steps 2 -> -1.00627 ± 0.000477452
# logging: k steps 3 -> -1.00627 ± 0.000524253
# logging: k steps 4 -> -1.00627 ± 0.000553788
# logging: k steps 5 -> -1.00627 ± 0.000570146
# 40 0.38 ---magnetization error:
# logging: k steps 1 -> 0.111993 ± 0.000779072
# logging: k steps 2 -> 0.111993 ± 0.00101051
# logging: k steps 3 -> 0.111993 ± 0.00125512
# logging: k steps 4 -> 0.111993 ± 0.00145183
# logging: k steps 5 -> 0.111993 ± 0.00162267
# 40 0.38 --- C error:
# logging: correl lenght 8 -> 1.42498e-07 ± 1.42944e-09
# logging: correl lenght 16 -> 1.42551e-07 ± 1.27759e-09
# logging: correl lenght 32 -> 1.42095e-07 ± 1.61167e-09
# logging: correl lenght 64 -> 1.42539e-07 ± 1.56977e-09
# logging: correl lenght 128 -> 1.42154e-07 ± 1.62481e-09
# 40 0.38 --- Ki error:
# logging: correl lenght 8 -> 3.42759e-07 ± 8.73897e-09
# logging: correl lenght 16 -> 3.44059e-07 ± 9.14253e-09
# logging: correl lenght 32 -> 3.43943e-07 ± 1.01937e-08
# logging: correl lenght 64 -> 3.43638e-07 ± 9.63964e-09
# logging: correl lenght 128 -> 3.4323e-07 ± 9.97136e-09
# 40 0.3825 ---energy error:
# logging: k steps 1 -> -1.01888 ± 0.000430794
# logging: k steps 2 -> -1.01888 ± 0.000485821
# logging: k steps 3 -> -1.01888 ± 0.000534845
# logging: k steps 4 -> -1.01888 ± 0.000566818
# logging: k steps 5 -> -1.01888 ± 0.000582512
# 40 0.3825 ---magnetization error:
# logging: k steps 1 -> 0.116894 ± 0.000820293
# logging: k steps 2 -> 0.116894 ± 0.00107254
# logging: k steps 3 -> 0.116894 ± 0.00134618
# logging: k steps 4 -> 0.116894 ± 0.00155489
# logging: k steps 5 -> 0.116894 ± 0.00164986
# 40 0.3825 --- C error:
# logging: correl lenght 8 -> 1.45183e-07 ± 1.59449e-09
# logging: correl lenght 16 -> 1.45025e-07 ± 1.56473e-09
# logging: correl lenght 32 -> 1.45101e-07 ± 1.68664e-09
# logging: correl lenght 64 -> 1.44908e-07 ± 1.72422e-09
# logging: correl lenght 128 -> 1.44854e-07 ± 1.54434e-09
# 40 0.3825 --- Ki error:
# logging: correl lenght 8 -> 3.76151e-07 ± 9.24659e-09
# logging: correl lenght 16 -> 3.76427e-07 ± 9.43804e-09
# logging: correl lenght 32 -> 3.76183e-07 ± 1.01491e-08
# logging: correl lenght 64 -> 3.77102e-07 ± 1.13486e-08
# logging: correl lenght 128 -> 3.76974e-07 ± 1.17096e-08
# 40 0.385 ---energy error:
# logging: k steps 1 -> -1.02981 ± 0.000442679
# logging: k steps 2 -> -1.02981 ± 0.000501279
# logging: k steps 3 -> -1.02981 ± 0.000553451
# logging: k steps 4 -> -1.02981 ± 0.000590019
# logging: k steps 5 -> -1.02981 ± 0.000605837
# 40 0.385 ---magnetization error:
# logging: k steps 1 -> 0.11917 ± 0.000827949
# logging: k steps 2 -> 0.11917 ± 0.00108375
# logging: k steps 3 -> 0.11917 ± 0.00135943
# logging: k steps 4 -> 0.11917 ± 0.0016098
# logging: k steps 5 -> 0.11917 ± 0.00175623
# 40 0.385 --- C error:
# logging: correl lenght 8 -> 1.49752e-07 ± 1.67812e-09
# logging: correl lenght 16 -> 1.49773e-07 ± 1.56696e-09
# logging: correl lenght 32 -> 1.49486e-07 ± 1.70357e-09
# logging: correl lenght 64 -> 1.49953e-07 ± 1.78914e-09
# logging: correl lenght 128 -> 1.49623e-07 ± 1.72788e-09
# 40 0.385 --- Ki error:
# logging: correl lenght 8 -> 3.82296e-07 ± 9.13452e-09
# logging: correl lenght 16 -> 3.81966e-07 ± 1.02529e-08
# logging: correl lenght 32 -> 3.82396e-07 ± 1.04827e-08
# logging: correl lenght 64 -> 3.81187e-07 ± 1.26106e-08
# logging: correl lenght 128 -> 3.83278e-07 ± 1.18451e-08
# 40 0.3875 ---energy error:
# logging: k steps 1 -> -1.04091 ± 0.000451628
# logging: k steps 2 -> -1.04091 ± 0.000515193
# logging: k steps 3 -> -1.04091 ± 0.000570403
# logging: k steps 4 -> -1.04091 ± 0.000621517
# logging: k steps 5 -> -1.04091 ± 0.000656515
# 40 0.3875 ---magnetization error:
# logging: k steps 1 -> 0.124224 ± 0.000869962
# logging: k steps 2 -> 0.124224 ± 0.00114864
# logging: k steps 3 -> 0.124224 ± 0.00145353
# logging: k steps 4 -> 0.124224 ± 0.00172528
# logging: k steps 5 -> 0.124224 ± 0.0019812
# 40 0.3875 --- C error:
# logging: correl lenght 8 -> 1.54254e-07 ± 1.79834e-09
# logging: correl lenght 16 -> 1.53938e-07 ± 2.04745e-09
# logging: correl lenght 32 -> 1.54133e-07 ± 1.89243e-09
# logging: correl lenght 64 -> 1.54483e-07 ± 2.02507e-09
# logging: correl lenght 128 -> 1.54164e-07 ± 1.77829e-09
# 40 0.3875 --- Ki error:
# logging: correl lenght 8 -> 4.17521e-07 ± 9.096e-09
# logging: correl lenght 16 -> 4.17448e-07 ± 1.28772e-08
# logging: correl lenght 32 -> 4.18165e-07 ± 1.2135e-08
# logging: correl lenght 64 -> 4.19424e-07 ± 1.28321e-08
# logging: correl lenght 128 -> 4.17063e-07 ± 1.32778e-08
# 40 0.39 ---energy error:
# logging: k steps 1 -> -1.0543 ± 0.000458845
# logging: k steps 2 -> -1.0543 ± 0.000524418
# logging: k steps 3 -> -1.0543 ± 0.000585494
# logging: k steps 4 -> -1.0543 ± 0.000634379
# logging: k steps 5 -> -1.0543 ± 0.000668717
# 40 0.39 ---magnetization error:
# logging: k steps 1 -> 0.129968 ± 0.000909342
# logging: k steps 2 -> 0.129968 ± 0.00120392
# logging: k steps 3 -> 0.129968 ± 0.00153118
# logging: k steps 4 -> 0.129968 ± 0.00184818
# logging: k steps 5 -> 0.129968 ± 0.00210494
# 40 0.39 --- C error:
# logging: correl lenght 8 -> 1.56419e-07 ± 1.67178e-09
# logging: correl lenght 16 -> 1.56053e-07 ± 1.91074e-09
# logging: correl lenght 32 -> 1.55922e-07 ± 2.00924e-09
# logging: correl lenght 64 -> 1.56462e-07 ± 1.91092e-09
# logging: correl lenght 128 -> 1.56154e-07 ± 1.69444e-09
# 40 0.39 --- Ki error:
# logging: correl lenght 8 -> 4.53803e-07 ± 1.20295e-08
# logging: correl lenght 16 -> 4.53054e-07 ± 1.23729e-08
# logging: correl lenght 32 -> 4.54419e-07 ± 1.30777e-08
# logging: correl lenght 64 -> 4.5386e-07 ± 1.44008e-08
# logging: correl lenght 128 -> 4.53474e-07 ± 1.40893e-08
# 40 0.3925 ---energy error:
# logging: k steps 1 -> -1.06786 ± 0.000461506
# logging: k steps 2 -> -1.06786 ± 0.000531069
# logging: k steps 3 -> -1.06786 ± 0.00059613
# logging: k steps 4 -> -1.06786 ± 0.000644743
# logging: k steps 5 -> -1.06786 ± 0.000649692
# 40 0.3925 ---magnetization error:
# logging: k steps 1 -> 0.139774 ± 0.000985059
# logging: k steps 2 -> 0.139774 ± 0.00131946
# logging: k steps 3 -> 0.139774 ± 0.00170435
# logging: k steps 4 -> 0.139774 ± 0.00209301
# logging: k steps 5 -> 0.139774 ± 0.00233993
# 40 0.3925 --- C error:
# logging: correl lenght 8 -> 1.58803e-07 ± 1.79064e-09
# logging: correl lenght 16 -> 1.58433e-07 ± 1.63365e-09
# logging: correl lenght 32 -> 1.58801e-07 ± 1.79347e-09
# logging: correl lenght 64 -> 1.58657e-07 ± 1.85927e-09
# logging: correl lenght 128 -> 1.59361e-07 ± 1.98502e-09
# 40 0.3925 --- Ki error:
# logging: correl lenght 8 -> 5.24471e-07 ± 1.35966e-08
# logging: correl lenght 16 -> 5.2665e-07 ± 1.53278e-08
# logging: correl lenght 32 -> 5.24869e-07 ± 1.5699e-08
# logging: correl lenght 64 -> 5.2673e-07 ± 1.96271e-08
# logging: correl lenght 128 -> 5.19552e-07 ± 1.56918e-08
# 40 0.395 ---energy error:
# logging: k steps 1 -> -1.08052 ± 0.000474062
# logging: k steps 2 -> -1.08052 ± 0.000554171
# logging: k steps 3 -> -1.08052 ± 0.000635044
# logging: k steps 4 -> -1.08052 ± 0.000703525
# logging: k steps 5 -> -1.08052 ± 0.000726118
# 40 0.395 ---magnetization error:
# logging: k steps 1 -> 0.144813 ± 0.00103436
# logging: k steps 2 -> 0.144813 ± 0.00139172
# logging: k steps 3 -> 0.144813 ± 0.00181529
# logging: k steps 4 -> 0.144813 ± 0.00225828
# logging: k steps 5 -> 0.144813 ± 0.00254903
# 40 0.395 --- C error:
# logging: correl lenght 8 -> 1.63637e-07 ± 2.20405e-09
# logging: correl lenght 16 -> 1.63829e-07 ± 1.83899e-09
# logging: correl lenght 32 -> 1.63725e-07 ± 1.85378e-09
# logging: correl lenght 64 -> 1.63823e-07 ± 2.1922e-09
# logging: correl lenght 128 -> 1.63653e-07 ± 2.06524e-09
# 40 0.395 --- Ki error:
# logging: correl lenght 8 -> 5.73772e-07 ± 1.41463e-08
# logging: correl lenght 16 -> 5.75747e-07 ± 1.63513e-08
# logging: correl lenght 32 -> 5.76418e-07 ± 2.15747e-08
# logging: correl lenght 64 -> 5.74018e-07 ± 2.12027e-08
# logging: correl lenght 128 -> 5.75443e-07 ± 1.95801e-08
# 40 0.3975 ---energy error:
# logging: k steps 1 -> -1.09155 ± 0.000475177
# logging: k steps 2 -> -1.09155 ± 0.000548363
# logging: k steps 3 -> -1.09155 ± 0.000620762
# logging: k steps 4 -> -1.09155 ± 0.000677163
# logging: k steps 5 -> -1.09155 ± 0.000746987
# 40 0.3975 ---magnetization error:
# logging: k steps 1 -> 0.149715 ± 0.00103462
# logging: k steps 2 -> 0.149715 ± 0.00138815
# logging: k steps 3 -> 0.149715 ± 0.00181607
# logging: k steps 4 -> 0.149715 ± 0.00223969
# logging: k steps 5 -> 0.149715 ± 0.00259456
# 40 0.3975 --- C error:
# logging: correl lenght 8 -> 1.65683e-07 ± 1.94291e-09
# logging: correl lenght 16 -> 1.65594e-07 ± 2.08097e-09
# logging: correl lenght 32 -> 1.65963e-07 ± 1.96466e-09
# logging: correl lenght 64 -> 1.65689e-07 ± 1.98556e-09
# logging: correl lenght 128 -> 1.65611e-07 ± 2.06398e-09
# 40 0.3975 --- Ki error:
# logging: correl lenght 8 -> 5.77819e-07 ± 1.09361e-08
# logging: correl lenght 16 -> 5.7909e-07 ± 1.52904e-08
# logging: correl lenght 32 -> 5.73369e-07 ± 1.76499e-08
# logging: correl lenght 64 -> 5.7566e-07 ± 1.67787e-08
# logging: correl lenght 128 -> 5.82125e-07 ± 1.98819e-08
# 40 0.4 ---energy error:
# logging: k steps 1 -> -1.10577 ± 0.000485249
# logging: k steps 2 -> -1.10577 ± 0.000571272
# logging: k steps 3 -> -1.10577 ± 0.000657612
# logging: k steps 4 -> -1.10577 ± 0.000729556
# logging: k steps 5 -> -1.10577 ± 0.000796056
# 40 0.4 ---magnetization error:
# logging: k steps 1 -> 0.160246 ± 0.00111684
# logging: k steps 2 -> 0.160246 ± 0.00151379
# logging: k steps 3 -> 0.160246 ± 0.00199289
# logging: k steps 4 -> 0.160246 ± 0.00248453
# logging: k steps 5 -> 0.160246 ± 0.00288219
# 40 0.4 --- C error:
# logging: correl lenght 8 -> 1.70007e-07 ± 2.35919e-09
# logging: correl lenght 16 -> 1.6979e-07 ± 2.05725e-09
# logging: correl lenght 32 -> 1.70264e-07 ± 2.07319e-09
# logging: correl lenght 64 -> 1.70195e-07 ± 1.84247e-09
# logging: correl lenght 128 -> 1.69786e-07 ± 2.16231e-09
# 40 0.4 --- Ki error:
# logging: correl lenght 8 -> 6.62001e-07 ± 1.70571e-08
# logging: correl lenght 16 -> 6.64129e-07 ± 1.8455e-08
# logging: correl lenght 32 -> 6.63005e-07 ± 1.75629e-08
# logging: correl lenght 64 -> 6.65825e-07 ± 2.21029e-08
# logging: correl lenght 128 -> 6.69247e-07 ± 2.31438e-08
# 40 0.4025 ---energy error:
# logging: k steps 1 -> -1.12023 ± 0.000495397
# logging: k steps 2 -> -1.12023 ± 0.000582907
# logging: k steps 3 -> -1.12023 ± 0.000677193
# logging: k steps 4 -> -1.12023 ± 0.0007661
# logging: k steps 5 -> -1.12023 ± 0.000823216
# 40 0.4025 ---magnetization error:
# logging: k steps 1 -> 0.16964 ± 0.0011907
# logging: k steps 2 -> 0.16964 ± 0.0016202
# logging: k steps 3 -> 0.16964 ± 0.00215219
# logging: k steps 4 -> 0.16964 ± 0.00273391
# logging: k steps 5 -> 0.16964 ± 0.0032537
# 40 0.4025 --- C error:
# logging: correl lenght 8 -> 1.7452e-07 ± 2.01313e-09
# logging: correl lenght 16 -> 1.75114e-07 ± 2.23851e-09
# logging: correl lenght 32 -> 1.7467e-07 ± 2.23107e-09
# logging: correl lenght 64 -> 1.74625e-07 ± 2.26359e-09
# logging: correl lenght 128 -> 1.74724e-07 ± 2.40111e-09
# 40 0.4025 --- Ki error:
# logging: correl lenght 8 -> 7.48593e-07 ± 1.63358e-08
# logging: correl lenght 16 -> 7.47623e-07 ± 2.04769e-08
# logging: correl lenght 32 -> 7.47725e-07 ± 2.08964e-08
# logging: correl lenght 64 -> 7.46601e-07 ± 2.49579e-08
# logging: correl lenght 128 -> 7.48642e-07 ± 2.55724e-08
# 40 0.405 ---energy error:
# logging: k steps 1 -> -1.13435 ± 0.000508917
# logging: k steps 2 -> -1.13435 ± 0.00060809
# logging: k steps 3 -> -1.13435 ± 0.000714226
# logging: k steps 4 -> -1.13435 ± 0.00082442
# logging: k steps 5 -> -1.13435 ± 0.000908992
# 40 0.405 ---magnetization error:
# logging: k steps 1 -> 0.180243 ± 0.00126681
# logging: k steps 2 -> 0.180243 ± 0.00173302
# logging: k steps 3 -> 0.180243 ± 0.00232326
# logging: k steps 4 -> 0.180243 ± 0.00299616
# ...
# logging: correl lenght 16 -> 6.03777e-08 ± 7.93918e-10
# logging: correl lenght 32 -> 6.02111e-08 ± 8.9185e-10
# logging: correl lenght 64 -> 6.0251e-08 ± 8.54226e-10
# logging: correl lenght 128 -> 6.02492e-08 ± 8.69252e-10
# 60 0.475 --- Ki error:
# logging: correl lenght 8 -> 2.82897e-08 ± 9.6877e-10
# logging: correl lenght 16 -> 2.81731e-08 ± 1.06442e-09
# logging: correl lenght 32 -> 2.81174e-08 ± 1.23853e-09
# logging: correl lenght 64 -> 2.83019e-08 ± 1.48332e-09
# logging: correl lenght 128 -> 2.81465e-08 ± 1.4447e-09
# 60 0.4775 ---energy error:
# logging: k steps 1 -> -1.66723 ± 0.00027703
# logging: k steps 2 -> -1.66723 ± 0.000319001
# logging: k steps 3 -> -1.66723 ± 0.000354935
# logging: k steps 4 -> -1.66723 ± 0.000380606
# logging: k steps 5 -> -1.66723 ± 0.000395512
# 60 0.4775 ---magnetization error:
# logging: k steps 1 -> 0.871738 ± 0.000202682
# logging: k steps 2 -> 0.871738 ± 0.000257018
# logging: k steps 3 -> 0.871738 ± 0.000312838
# logging: k steps 4 -> 0.871738 ± 0.000362961
# logging: k steps 5 -> 0.871738 ± 0.000397756
# 60 0.4775 --- C error:
# logging: correl lenght 8 -> 5.71385e-08 ± 5.67598e-10
# logging: correl lenght 16 -> 5.71237e-08 ± 5.93205e-10
# logging: correl lenght 32 -> 5.70056e-08 ± 5.62025e-10
# logging: correl lenght 64 -> 5.70447e-08 ± 6.84176e-10
# logging: correl lenght 128 -> 5.72454e-08 ± 8.64666e-10
# 60 0.4775 --- Ki error:
# logging: correl lenght 8 -> 2.50322e-08 ± 6.37078e-10
# logging: correl lenght 16 -> 2.48952e-08 ± 7.52064e-10
# logging: correl lenght 32 -> 2.48324e-08 ± 7.91113e-10
# logging: correl lenght 64 -> 2.47933e-08 ± 9.77002e-10
# logging: correl lenght 128 -> 2.50321e-08 ± 8.77827e-10
# 60 0.48 ---energy error:
# logging: k steps 1 -> -1.67791 ± 0.00027115
# logging: k steps 2 -> -1.67791 ± 0.000306941
# logging: k steps 3 -> -1.67791 ± 0.000338996
# logging: k steps 4 -> -1.67791 ± 0.000374557
# logging: k steps 5 -> -1.67791 ± 0.000397695
# 60 0.48 ---magnetization error:
# logging: k steps 1 -> 0.877905 ± 0.00018931
# logging: k steps 2 -> 0.877905 ± 0.000236403
# logging: k steps 3 -> 0.877905 ± 0.000284333
# logging: k steps 4 -> 0.877905 ± 0.000330098
# logging: k steps 5 -> 0.877905 ± 0.000363703
# 60 0.48 --- C error:
# logging: correl lenght 8 -> 5.47382e-08 ± 6.86428e-10
# logging: correl lenght 16 -> 5.46847e-08 ± 6.36316e-10
# logging: correl lenght 32 -> 5.47295e-08 ± 6.08489e-10
# logging: correl lenght 64 -> 5.46905e-08 ± 5.91339e-10
# logging: correl lenght 128 -> 5.47459e-08 ± 6.14835e-10
# 60 0.48 --- Ki error:
# logging: correl lenght 8 -> 2.2064e-08 ± 6.27791e-10
# logging: correl lenght 16 -> 2.21113e-08 ± 7.80023e-10
# logging: correl lenght 32 -> 2.19911e-08 ± 8.18676e-10
# logging: correl lenght 64 -> 2.21255e-08 ± 9.60144e-10
# logging: correl lenght 128 -> 2.2245e-08 ± 9.62195e-10
# 60 0.4825 ---energy error:
# logging: k steps 1 -> -1.68738 ± 0.000266104
# logging: k steps 2 -> -1.68738 ± 0.000305118
# logging: k steps 3 -> -1.68738 ± 0.000342161
# logging: k steps 4 -> -1.68738 ± 0.000368269
# logging: k steps 5 -> -1.68738 ± 0.000387988
# 60 0.4825 ---magnetization error:
# logging: k steps 1 -> 0.882791 ± 0.000178847
# logging: k steps 2 -> 0.882791 ± 0.000223242
# logging: k steps 3 -> 0.882791 ± 0.000267552
# logging: k steps 4 -> 0.882791 ± 0.000303111
# logging: k steps 5 -> 0.882791 ± 0.000335378
# 60 0.4825 --- C error:
# logging: correl lenght 8 -> 5.2956e-08 ± 6.03579e-10
# logging: correl lenght 16 -> 5.29139e-08 ± 6.77902e-10
# logging: correl lenght 32 -> 5.29108e-08 ± 6.33143e-10
# logging: correl lenght 64 -> 5.292e-08 ± 7.03561e-10
# logging: correl lenght 128 -> 5.27916e-08 ± 6.75824e-10
# 60 0.4825 --- Ki error:
# logging: correl lenght 8 -> 1.99716e-08 ± 4.4235e-10
# logging: correl lenght 16 -> 2.00816e-08 ± 5.61209e-10
# logging: correl lenght 32 -> 2.006e-08 ± 6.15076e-10
# logging: correl lenght 64 -> 1.98726e-08 ± 5.85049e-10
# logging: correl lenght 128 -> 1.99437e-08 ± 6.04224e-10
# 60 0.485 ---energy error:
# logging: k steps 1 -> -1.69635 ± 0.000260516
# logging: k steps 2 -> -1.69635 ± 0.000297634
# logging: k steps 3 -> -1.69635 ± 0.000328268
# logging: k steps 4 -> -1.69635 ± 0.000354472
# logging: k steps 5 -> -1.69635 ± 0.00037688
# 60 0.485 ---magnetization error:
# logging: k steps 1 -> 0.88713 ± 0.000180129
# logging: k steps 2 -> 0.88713 ± 0.000226687
# logging: k steps 3 -> 0.88713 ± 0.00027515
# logging: k steps 4 -> 0.88713 ± 0.000325594
# logging: k steps 5 -> 0.88713 ± 0.00037339
# 60 0.485 --- C error:
# logging: correl lenght 8 -> 5.14104e-08 ± 6.85381e-10
# logging: correl lenght 16 -> 5.14167e-08 ± 5.5617e-10
# logging: correl lenght 32 -> 5.14468e-08 ± 5.90803e-10
# logging: correl lenght 64 -> 5.14564e-08 ± 7.0677e-10
# logging: correl lenght 128 -> 5.13791e-08 ± 8.02591e-10
# 60 0.485 --- Ki error:
# logging: correl lenght 8 -> 2.00678e-08 ± 8.08507e-10
# logging: correl lenght 16 -> 2.00741e-08 ± 1.10665e-09
# logging: correl lenght 32 -> 2.00257e-08 ± 1.09486e-09
# logging: correl lenght 64 -> 1.97811e-08 ± 1.28115e-09
# logging: correl lenght 128 -> 2.01868e-08 ± 1.40221e-09
# 60 0.4875 ---energy error:
# logging: k steps 1 -> -1.70565 ± 0.000249015
# logging: k steps 2 -> -1.70565 ± 0.000280888
# logging: k steps 3 -> -1.70565 ± 0.000308331
# logging: k steps 4 -> -1.70565 ± 0.000331533
# logging: k steps 5 -> -1.70565 ± 0.000348274
# 60 0.4875 ---magnetization error:
# logging: k steps 1 -> 0.892301 ± 0.000161539
# logging: k steps 2 -> 0.892301 ± 0.000199725
# logging: k steps 3 -> 0.892301 ± 0.000237704
# logging: k steps 4 -> 0.892301 ± 0.000276275
# logging: k steps 5 -> 0.892301 ± 0.00031753
# 60 0.4875 --- C error:
# logging: correl lenght 8 -> 4.84153e-08 ± 5.35793e-10
# logging: correl lenght 16 -> 4.83674e-08 ± 5.85712e-10
# logging: correl lenght 32 -> 4.83054e-08 ± 5.83981e-10
# logging: correl lenght 64 -> 4.83265e-08 ± 6.54464e-10
# logging: correl lenght 128 -> 4.82509e-08 ± 6.16288e-10
# 60 0.4875 --- Ki error:
# logging: correl lenght 8 -> 1.66933e-08 ± 4.83656e-10
# logging: correl lenght 16 -> 1.68472e-08 ± 6.38667e-10
# logging: correl lenght 32 -> 1.6789e-08 ± 7.44944e-10
# logging: correl lenght 64 -> 1.67004e-08 ± 7.54014e-10
# logging: correl lenght 128 -> 1.66369e-08 ± 8.19724e-10
# 60 0.49 ---energy error:
# logging: k steps 1 -> -1.71431 ± 0.000244086
# logging: k steps 2 -> -1.71431 ± 0.000273969
# logging: k steps 3 -> -1.71431 ± 0.000297206
# logging: k steps 4 -> -1.71431 ± 0.000321325
# logging: k steps 5 -> -1.71431 ± 0.00033297
# 60 0.49 ---magnetization error:
# logging: k steps 1 -> 0.896781 ± 0.000149147
# logging: k steps 2 -> 0.896781 ± 0.000181268
# logging: k steps 3 -> 0.896781 ± 0.000209915
# logging: k steps 4 -> 0.896781 ± 0.000233557
# logging: k steps 5 -> 0.896781 ± 0.000243762
# 60 0.49 --- C error:
# logging: correl lenght 8 -> 4.6312e-08 ± 5.39192e-10
# logging: correl lenght 16 -> 4.64057e-08 ± 5.29235e-10
# logging: correl lenght 32 -> 4.63363e-08 ± 4.80544e-10
# logging: correl lenght 64 -> 4.63289e-08 ± 5.0847e-10
# logging: correl lenght 128 -> 4.63648e-08 ± 4.79226e-10
# 60 0.49 --- Ki error:
# logging: correl lenght 8 -> 1.45225e-08 ± 2.99468e-10
# logging: correl lenght 16 -> 1.46394e-08 ± 2.97253e-10
# logging: correl lenght 32 -> 1.4553e-08 ± 3.18967e-10
# logging: correl lenght 64 -> 1.4569e-08 ± 3.34549e-10
# logging: correl lenght 128 -> 1.45648e-08 ± 3.29228e-10
# 60 0.4925 ---energy error:
# logging: k steps 1 -> -1.72243 ± 0.00023929
# logging: k steps 2 -> -1.72243 ± 0.000265583
# logging: k steps 3 -> -1.72243 ± 0.000293101
# logging: k steps 4 -> -1.72243 ± 0.000302783
# logging: k steps 5 -> -1.72243 ± 0.00032139
# 60 0.4925 ---magnetization error:
# logging: k steps 1 -> 0.900392 ± 0.000146056
# logging: k steps 2 -> 0.900392 ± 0.000177427
# logging: k steps 3 -> 0.900392 ± 0.000209476
# logging: k steps 4 -> 0.900392 ± 0.000227897
# logging: k steps 5 -> 0.900392 ± 0.000250288
# 60 0.4925 --- C error:
# logging: correl lenght 8 -> 4.44141e-08 ± 4.40569e-10
# logging: correl lenght 16 -> 4.45504e-08 ± 5.2123e-10
# logging: correl lenght 32 -> 4.44339e-08 ± 5.02845e-10
# logging: correl lenght 64 -> 4.4422e-08 ± 4.7542e-10
# logging: correl lenght 128 -> 4.44848e-08 ± 5.44071e-10
# 60 0.4925 --- Ki error:
# logging: correl lenght 8 -> 1.38835e-08 ± 3.45415e-10
# logging: correl lenght 16 -> 1.38475e-08 ± 3.66579e-10
# logging: correl lenght 32 -> 1.39059e-08 ± 4.11698e-10
# logging: correl lenght 64 -> 1.38385e-08 ± 3.82271e-10
# logging: correl lenght 128 -> 1.38815e-08 ± 3.95862e-10
# 60 0.495 ---energy error:
# logging: k steps 1 -> -1.73046 ± 0.000235311
# logging: k steps 2 -> -1.73046 ± 0.000260244
# logging: k steps 3 -> -1.73046 ± 0.000282438
# logging: k steps 4 -> -1.73046 ± 0.000294996
# logging: k steps 5 -> -1.73046 ± 0.000308437
# 60 0.495 ---magnetization error:
# logging: k steps 1 -> 0.904255 ± 0.000137765
# logging: k steps 2 -> 0.904255 ± 0.000165218
# logging: k steps 3 -> 0.904255 ± 0.000192608
# logging: k steps 4 -> 0.904255 ± 0.000212086
# logging: k steps 5 -> 0.904255 ± 0.000233002
# 60 0.495 --- C error:
# logging: correl lenght 8 -> 4.32502e-08 ± 4.21075e-10
# logging: correl lenght 16 -> 4.33347e-08 ± 5.11426e-10
# logging: correl lenght 32 -> 4.33127e-08 ± 5.61124e-10
# logging: correl lenght 64 -> 4.32955e-08 ± 5.02379e-10
# logging: correl lenght 128 -> 4.32506e-08 ± 5.40581e-10
# 60 0.495 --- Ki error:
# logging: correl lenght 8 -> 1.2567e-08 ± 2.8016e-10
# logging: correl lenght 16 -> 1.25752e-08 ± 3.50108e-10
# logging: correl lenght 32 -> 1.25572e-08 ± 3.96186e-10
# logging: correl lenght 64 -> 1.25631e-08 ± 3.99365e-10
# logging: correl lenght 128 -> 1.25728e-08 ± 4.14079e-10
# 60 0.4975 ---energy error:
# logging: k steps 1 -> -1.73825 ± 0.00023052
# logging: k steps 2 -> -1.73825 ± 0.000254452
# logging: k steps 3 -> -1.73825 ± 0.000273255
# logging: k steps 4 -> -1.73825 ± 0.000282837
# logging: k steps 5 -> -1.73825 ± 0.000294424
# 60 0.4975 ---magnetization error:
# logging: k steps 1 -> 0.907953 ± 0.000130001
# logging: k steps 2 -> 0.907953 ± 0.000154929
# logging: k steps 3 -> 0.907953 ± 0.00017702
# logging: k steps 4 -> 0.907953 ± 0.000193761
# logging: k steps 5 -> 0.907953 ± 0.000208798
# 60 0.4975 --- C error:
# logging: correl lenght 8 -> 4.20465e-08 ± 4.36511e-10
# logging: correl lenght 16 -> 4.19383e-08 ± 4.45119e-10
# logging: correl lenght 32 -> 4.19577e-08 ± 4.57365e-10
# logging: correl lenght 64 -> 4.19801e-08 ± 4.4693e-10
# logging: correl lenght 128 -> 4.19318e-08 ± 4.69955e-10
# 60 0.4975 --- Ki error:
# logging: correl lenght 8 -> 1.14534e-08 ± 2.40819e-10
# logging: correl lenght 16 -> 1.14873e-08 ± 2.93334e-10
# logging: correl lenght 32 -> 1.14472e-08 ± 3.17973e-10
# logging: correl lenght 64 -> 1.14758e-08 ± 3.45209e-10
# logging: correl lenght 128 -> 1.14438e-08 ± 3.33039e-10
# 60 0.5 ---energy error:
# logging: k steps 1 -> -1.7458 ± 0.000221816
# logging: k steps 2 -> -1.7458 ± 0.000240479
# logging: k steps 3 -> -1.7458 ± 0.000259532
# logging: k steps 4 -> -1.7458 ± 0.000276997
# logging: k steps 5 -> -1.7458 ± 0.000281958
# 60 0.5 ---magnetization error:
# logging: k steps 1 -> 0.911286 ± 0.00013093
# logging: k steps 2 -> 0.911286 ± 0.000157994
# logging: k steps 3 -> 0.911286 ± 0.000188097
# logging: k steps 4 -> 0.911286 ± 0.000222307
# logging: k steps 5 -> 0.911286 ± 0.000241376
# 60 0.5 --- C error:
# logging: correl lenght 8 -> 3.95861e-08 ± 4.25161e-10
# logging: correl lenght 16 -> 3.96049e-08 ± 4.48108e-10
# logging: correl lenght 32 -> 3.9598e-08 ± 4.32472e-10
# logging: correl lenght 64 -> 3.97044e-08 ± 4.97093e-10
# logging: correl lenght 128 -> 3.96343e-08 ± 4.62026e-10
# 60 0.5 --- Ki error:
# logging: correl lenght 8 -> 1.14789e-08 ± 4.01424e-10
# logging: correl lenght 16 -> 1.15108e-08 ± 6.39387e-10
# logging: correl lenght 32 -> 1.1463e-08 ± 7.6168e-10
# logging: correl lenght 64 -> 1.15106e-08 ± 6.68438e-10
# logging: correl lenght 128 -> 1.15664e-08 ± 9.03099e-10
# 60 0.5025 ---energy error:
# logging: k steps 1 -> -1.75278 ± 0.000216783
# logging: k steps 2 -> -1.75278 ± 0.000237093
# logging: k steps 3 -> -1.75278 ± 0.000248383
# logging: k steps 4 -> -1.75278 ± 0.000256379
# logging: k steps 5 -> -1.75278 ± 0.000263789
# 60 0.5025 ---magnetization error:
# logging: k steps 1 -> 0.914653 ± 0.000117595
# logging: k steps 2 -> 0.914653 ± 0.000138182
# logging: k steps 3 -> 0.914653 ± 0.000155511
# logging: k steps 4 -> 0.914653 ± 0.000168253
# logging: k steps 5 -> 0.914653 ± 0.000178139
# 60 0.5025 --- C error:
# logging: correl lenght 8 -> 3.78851e-08 ± 3.70001e-10
# logging: correl lenght 16 -> 3.79732e-08 ± 3.82995e-10
# logging: correl lenght 32 -> 3.79027e-08 ± 3.90373e-10
# logging: correl lenght 64 -> 3.79699e-08 ± 4.19474e-10
# logging: correl lenght 128 -> 3.80296e-08 ± 4.10535e-10
# 60 0.5025 --- Ki error:
# logging: correl lenght 8 -> 9.62375e-09 ± 1.98255e-10
# logging: correl lenght 16 -> 9.62144e-09 ± 2.0141e-10
# logging: correl lenght 32 -> 9.65121e-09 ± 2.19239e-10
# logging: correl lenght 64 -> 9.62283e-09 ± 2.04351e-10
# logging: correl lenght 128 -> 9.65597e-09 ± 2.06074e-10
# 60 0.505 ---energy error:
# logging: k steps 1 -> -1.75979 ± 0.000214326
# logging: k steps 2 -> -1.75979 ± 0.000231886
# logging: k steps 3 -> -1.75979 ± 0.000244086
# logging: k steps 4 -> -1.75979 ± 0.000249477
# logging: k steps 5 -> -1.75979 ± 0.000251347
# 60 0.505 ---magnetization error:
# logging: k steps 1 -> 0.917727 ± 0.000113444
# logging: k steps 2 -> 0.917727 ± 0.000131796
# logging: k steps 3 -> 0.917727 ± 0.000147784
# logging: k steps 4 -> 0.917727 ± 0.000158709
# logging: k steps 5 -> 0.917727 ± 0.00016311
# 60 0.505 --- C error:
# logging: correl lenght 8 -> 3.73252e-08 ± 3.96993e-10
# logging: correl lenght 16 -> 3.72922e-08 ± 4.22876e-10
# logging: correl lenght 32 -> 3.73047e-08 ± 3.83332e-10
# logging: correl lenght 64 -> 3.73117e-08 ± 3.83933e-10
# logging: correl lenght 128 -> 3.73806e-08 ± 4.63601e-10
# 60 0.505 --- Ki error:
# logging: correl lenght 8 -> 9.01105e-09 ± 2.028e-10
# logging: correl lenght 16 -> 9.03798e-09 ± 2.23128e-10
# logging: correl lenght 32 -> 8.98623e-09 ± 2.09914e-10
# logging: correl lenght 64 -> 8.98254e-09 ± 2.4684e-10
# logging: correl lenght 128 -> 9.03657e-09 ± 2.24023e-10
# 60 0.5075 ---energy error:
# logging: k steps 1 -> -1.76597 ± 0.000210247
# logging: k steps 2 -> -1.76597 ± 0.000227206
# logging: k steps 3 -> -1.76597 ± 0.000240079
# logging: k steps 4 -> -1.76597 ± 0.000244302
# logging: k steps 5 -> -1.76597 ± 0.000251145
# 60 0.5075 ---magnetization error:
# logging: k steps 1 -> 0.92033 ± 0.000110852
# logging: k steps 2 -> 0.92033 ± 0.000129123
# logging: k steps 3 -> 0.92033 ± 0.00014561
# logging: k steps 4 -> 0.92033 ± 0.000155008
# logging: k steps 5 -> 0.92033 ± 0.000163347
# 60 0.5075 --- C error:
# logging: correl lenght 8 -> 3.62144e-08 ± 3.51468e-10
# logging: correl lenght 16 -> 3.61822e-08 ± 3.84823e-10
# logging: correl lenght 32 -> 3.61169e-08 ± 3.60511e-10
# logging: correl lenght 64 -> 3.62047e-08 ± 3.67259e-10
# logging: correl lenght 128 -> 3.61899e-08 ± 3.79701e-10
# 60 0.5075 --- Ki error:
# logging: correl lenght 8 -> 8.61225e-09 ± 1.80624e-10
# logging: correl lenght 16 -> 8.63403e-09 ± 1.93204e-10
# logging: correl lenght 32 -> 8.61816e-09 ± 2.07759e-10
# logging: correl lenght 64 -> 8.6159e-09 ± 1.96342e-10
# logging: correl lenght 128 -> 8.62761e-09 ± 2.36502e-10
# 60 0.51 ---energy error:
# logging: k steps 1 -> -1.77245 ± 0.000203759
# logging: k steps 2 -> -1.77245 ± 0.000221929
# logging: k steps 3 -> -1.77245 ± 0.000233938
# logging: k steps 4 -> -1.77245 ± 0.00024573
# logging: k steps 5 -> -1.77245 ± 0.000254267
# 60 0.51 ---magnetization error:
# logging: k steps 1 -> 0.923172 ± 0.000103934
# logging: k steps 2 -> 0.923172 ± 0.000120002
# logging: k steps 3 -> 0.923172 ± 0.000132737
# logging: k steps 4 -> 0.923172 ± 0.000143189
# logging: k steps 5 -> 0.923172 ± 0.000147978
# 60 0.51 --- C error:
# logging: correl lenght 8 -> 3.48595e-08 ± 3.35747e-10
# logging: correl lenght 16 -> 3.48342e-08 ± 3.62833e-10
# logging: correl lenght 32 -> 3.48154e-08 ± 3.73059e-10
# logging: correl lenght 64 -> 3.48492e-08 ± 3.90626e-10
# logging: correl lenght 128 -> 3.48157e-08 ± 3.347e-10
# 60 0.51 --- Ki error:
# logging: correl lenght 8 -> 7.87795e-09 ± 1.35529e-10
# logging: correl lenght 16 -> 7.86856e-09 ± 1.35532e-10
# logging: correl lenght 32 -> 7.89237e-09 ± 1.48268e-10
# logging: correl lenght 64 -> 7.87261e-09 ± 1.41872e-10
# logging: correl lenght 128 -> 7.89896e-09 ± 1.45456e-10
# The work is done.

# %%
# !sudo apt-get install g++

# %%
# %run pythoninterface.py

# %%
# %run ANNA_pythoninterface.py

# %% [markdown]
# Make calculations and stuff with the output

# %%
a = np.loadtxt('data.dat', unpack='True')

x = a[0, :]
y = a[1, :]
z = a[2, :]

# %%
plt.figure("Figura 1")
plt.scatter(x, y, label='Points')
plt.xlabel('Numeri')
plt.ylabel('Risultati')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# At last, remove things you don't need anymore and move to the main directory

# %%
# With bash commands
# !rm run_ising

# With python commands
#os.system('rm run_ising')

# %%
# %cd ..

# %% [markdown]
# # Module 2
#
# Quantum Ising 1D

# %%
# %cd 2.Ising_Q1D/

# %%
# %cd ..

# %% [markdown]
# # Module 3
#
# Path integral simulation

# %%
# %cd 3.Path_integral/

# %%
# %cd ..

# %% [markdown]
# #Push to GitHub

# %%
# !git pull          # update your local version of the repository
# Out:
# Already up to date.

# %%
# !git status        # check the changes you made to your local version of the repository
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   Side_20/averages_and_variance.dat
# 	modified:   Side_30/averages_and_variance.dat
# 	modified:   Side_40/averages_and_variance.dat
# 	modified:   Side_50/averages_and_variance.dat
# 	modified:   Side_60/averages_and_variance.dat
# 	new file:   data.out
# 	modified:   data_analysis.cpp

# %%
# !git add .         # add the changes that you want to save, to the commit list

# %%
# Anna
# !git config user.email "nanacaliendo@gmail.com"
# !git config user.name  "Melanna7"

# Dario
#!git config user.email "cafasso.dario@gmail.com"
#!git config user.name  "Dario_Maglio"

# %%
# !git commit -m "implemented bootstrap and blocking algorithm in ising 2D"    # save changes in your local version of the repository
# Out:
# [main 0dcce62] implemented bootstrap and blocking algorithm in ising 2D
#  7 files changed, 438 insertions(+), 312 deletions(-)
#  rewrite Application_projects/Ising_model_2D/Side_20/averages_and_variance.dat (100%)
#  rewrite Application_projects/Ising_model_2D/Side_30/averages_and_variance.dat (100%)
#  rewrite Application_projects/Ising_model_2D/Side_40/averages_and_variance.dat (100%)
#  rewrite Application_projects/Ising_model_2D/Side_50/averages_and_variance.dat (100%)
#  rewrite Application_projects/Ising_model_2D/Side_60/averages_and_variance.dat (100%)
#  create mode 100755 Application_projects/Ising_model_2D/data.out

# %%
# Generate the <TOKEN> in Profile/Setting/Developer_setting/Personal_access_token
# !git push https://Dario-Maglio:<TOKEN>@github.com/Dario-Maglio/Numerical_Methods.git  # save changes on GitHub
# Out:
# Counting objects: 16, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (16/16), done.
# Writing objects: 100% (16/16), 31.34 KiB | 6.27 MiB/s, done.
# Total 16 (delta 7), reused 0 (delta 0)
# remote: Resolving deltas: 100% (7/7), completed with 7 local objects.
# To https://github.com/Dario-Maglio/Numerical_Methods.git
#    cf393a0..0dcce62  main -> main
